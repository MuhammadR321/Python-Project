# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadR321/Python-Project/blob/main/BrentOilPrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

#graphing data
import matplotlib.pyplot as plt
plt.style.use('classic')

data_source_file = 'BrentOilPrices.csv'
df_pop = pd.read_csv(data_source_file)
df_pop.info()

df_pop.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8554 entries, 0 to 8553
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8554 non-null   object
#  1   Price   8554 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 133.8+ KB
#          Date  Price
# 0   20-May-87  18.63
# 1   21-May-87  18.45
# 2   22-May-87  18.55
# 3   25-May-87  18.60
# 4   26-May-87  18.63
# ..        ...    ...
# 95   1-Oct-87  18.50
# 96   2-Oct-87  18.65
# 97   5-Oct-87  18.78
# 98   6-Oct-87  18.60
# 99   7-Oct-87  18.58
#
# [100 rows x 2 columns]

# %%
df_pop_by_date = df_pop.set_index('Date')
df_pop_by_date.plot(xlabel = 'Date', ylabel = 'Price')
plt.yticks(rotation = 45)
plt.xticks(rotation = 90)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000., 7000., 8000.,
#         9000.]), <a list of 10 Text major ticklabel objects>)
